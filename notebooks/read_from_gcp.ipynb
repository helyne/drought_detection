# %%
# imports
import os
import numpy as np
import tensorflow as tf
from google.cloud import storage
import tempfile
# import cv2
# from drought_detection.params import BUCKET_NAME, BUCKET_TRAIN_DATA_PATH

# %% [markdown]
# ## AVAILABLE BANDWIDTHS

# %%
# features = {
#   'B1': tf.FixedLenFeature([], tf.string),    # 0.43 - 0.45 μm Coastal aerosol
#   'B2': tf.FixedLenFeature([], tf.string),    # Blue
#   'B3': tf.FixedLenFeature([], tf.string),    # Green
#   'B4': tf.FixedLenFeature([], tf.string),    # Red
#   'B5': tf.FixedLenFeature([], tf.string),    # Near infrared
#   'B6': tf.FixedLenFeature([], tf.string),    # Shortwave infrared 1
#   'B7': tf.FixedLenFeature([], tf.string),    # Shortwave infrared 2
#   'B8': tf.FixedLenFeature([], tf.string),
#   'B9': tf.FixedLenFeature([], tf.string),
#   'B10': tf.FixedLenFeature([], tf.string),
#   'B11': tf.FixedLenFeature([], tf.string),
#   'label': tf.FixedLenFeature([], tf.int64),
# }

# %% [markdown]
# # Get and filter raw satellite data for specific spectral bands

# %%
def parse_visual(data):
    '''
    This function filters satellite image data by specific spectral bands (RGB in this case).
    The function loads a batch of satellite images from a list of files
    and parses the satellite image data files for some specific features,
    e.g. spectral bands (B2, B3, B4, see official documentation)

    Input(s): - list of satellite image files (including path, e.g '/data/train/part-r-00000')
    Outputs:  - list of dictionaries of raw satellite data (filtered by spectral band)
    '''
    dataset = tf.data.TFRecordDataset(data)

    iterator = tf.compat.v1.data.make_one_shot_iterator(dataset)

    features = {
        'B2': tf.compat.v1.FixedLenFeature([], tf.string), # blue spectral band
        'B3': tf.compat.v1.FixedLenFeature([], tf.string), # green spectral band
        'B4': tf.compat.v1.FixedLenFeature([], tf.string), # red spectral band
        'label': tf.compat.v1.FixedLenFeature([], tf.int64), # image label (0/1/2/3)
    }

    parsed_sat_imgs = [tf.compat.v1.parse_single_example(data, features) for data in iterator]
    return parsed_sat_imgs

# %% [markdown]
# # Transform each raw satellite image into an RGB array with label

# %%
def get_img_from_example(parsed_sat_img, intensify=True):
    '''
    This function creates an RGB 3D array in shape 65x65x3 (65x65 pixels). 
    Then it loads, for some bands / features (B4, B3, B2) a batch of satellite
    images, reshapes it from the Tensorflow specific data format into a 2D array of dimension 65x65 pixels.
    Next, it does some preprocessing, e.g. divides each pixel by the maximum value of the pixels, and
    multiplies every pixel by 255. Only if  intensity=True (please double check).
    Otherwise,, if intensify=False, it just multiplies each value in the matrix by 255.
    last, it adds a label (please double check), and returns the image 2D array, as well as the label.

    Input: - a parsed satellite image: Specific Tensorflow format (as dictionary)
    Output(s) - satellite image & its label:
                - rgbArray: tuple of 3D numpy array (shape 65x65x3)
                - label: int32
    '''
    rgbArray = np.zeros((65,65,3), 'uint8')
    for i, band in enumerate(['B4', 'B3', 'B2']):
        band_data = np.frombuffer(parsed_sat_img[band].numpy(), dtype=np.uint8)
        band_data = band_data.reshape(65, 65)
        if intensify:
            band_data = band_data/np.max(band_data)*255 # are we transforming the image from bytes to digital numbers by multiplying by 255?
        else:
            band_data = band_data*255
        rgbArray[..., i] = band_data

    label = tf.cast(parsed_sat_img['label'], tf.int32).numpy()

    return rgbArray, label

# %% [markdown]
# # Load images from GCP and process them

# %%
# # set bucket parameters
# BUCKET_NAME = 'wagon-data-batch913-drought_detection'
# BUCKET_TRAIN_DATA_PATH = 'data/train/'

# %% [markdown]
# ## try to load blobs without for loop (simple way)

# %%
# simple way

# GCP bucket parameters
project_name='drought-detection'
bucket_name = 'wagon-data-batch913-drought_detection'

# open storage client
storage_client = storage.Client(project=project_name)

# create blobs from the files starting with "part"
blobs = storage_client.list_blobs(bucket_name, prefix='data/train/part', delimiter='/')

# %%
# print blob file names
for blob in blobs:
    print(blob.name)
# Out:
# data/train/part-r-00000
# data/train/part-r-00001
# data/train/part-r-00002
# data/train/part-r-00003
# data/train/part-r-00004
# data/train/part-r-00005
# data/train/part-r-00006
# data/train/part-r-00007
# data/train/part-r-00008
# data/train/part-r-00009
# data/train/part-r-00010
# data/train/part-r-00011
# data/train/part-r-00012
# data/train/part-r-00013
# data/train/part-r-00014
# data/train/part-r-00015
# data/train/part-r-00016
# data/train/part-r-00017
# data/train/part-r-00018
# data/train/part-r-00019
# data/train/part-r-00020
# data/train/part-r-00021
# data/train/part-r-00022
# data/train/part-r-00023
# data/train/part-r-00024
# data/train/part-r-00025
# data/train/part-r-00026
# data/train/part-r-00027
# data/train/part-r-00028
# data/train/part-r-00029
# data/train/part-r-00030
# data/train/part-r-00031
# data/train/part-r-00032
# data/train/part-r-00033
# data/train/part-r-00034
# data/train/part-r-00035
# data/train/part-r-00036
# data/train/part-r-00037
# data/train/part-r-00038
# data/train/part-r-00039
# data/train/part-r-00040
# data/train/part-r-00041
# data/train/part-r-00042
# data/train/part-r-00043
# data/train/part-r-00044
# data/train/part-r-00045
# data/train/part-r-00046
# data/train/part-r-00047
# data/train/part-r-00048
# data/train/part-r-00049
# data/train/part-r-00050
# data/train/part-r-00051
# data/train/part-r-00052
# data/train/part-r-00053
# data/train/part-r-00054
# data/train/part-r-00055
# data/train/part-r-00056
# data/train/part-r-00057
# data/train/part-r-00058
# data/train/part-r-00059
# data/train/part-r-00060
# data/train/part-r-00061
# data/train/part-r-00062
# data/train/part-r-00063
# data/train/part-r-00064
# data/train/part-r-00065
# data/train/part-r-00066
# data/train/part-r-00067
# data/train/part-r-00068
# data/train/part-r-00069
# data/train/part-r-00070
# data/train/part-r-00071
# data/train/part-r-00072
# data/train/part-r-00073
# data/train/part-r-00074
# data/train/part-r-00075
# data/train/part-r-00076
# data/train/part-r-00077
# data/train/part-r-00078
# data/train/part-r-00079
# data/train/part-r-00080
# data/train/part-r-00081
# data/train/part-r-00082
# data/train/part-r-00083
# data/train/part-r-00084
# data/train/part-r-00085
# data/train/part-r-00086
# data/train/part-r-00087
# data/train/part-r-00088
# data/train/part-r-00089
# data/train/part-r-00090
# data/train/part-r-00091
# data/train/part-r-00092
# data/train/part-r-00093
# data/train/part-r-00094
# data/train/part-r-00095
# data/train/part-r-00096
# data/train/part-r-00097
# data/train/part-r-00098
# data/train/part-r-00099
# data/train/part-r-00100
# data/train/part-r-00101
# data/train/part-r-00102
# data/train/part-r-00103
# data/train/part-r-00104
# data/train/part-r-00105
# data/train/part-r-00106
# data/train/part-r-00107
# data/train/part-r-00108
# data/train/part-r-00109
# data/train/part-r-00110
# data/train/part-r-00111
# data/train/part-r-00112
# data/train/part-r-00113
# data/train/part-r-00114
# data/train/part-r-00115
# data/train/part-r-00116
# data/train/part-r-00117
# data/train/part-r-00118
# data/train/part-r-00119
# data/train/part-r-00120
# data/train/part-r-00121
# data/train/part-r-00122
# data/train/part-r-00123
# data/train/part-r-00124
# data/train/part-r-00125
# data/train/part-r-00126
# data/train/part-r-00127
# data/train/part-r-00128
# data/train/part-r-00129
# data/train/part-r-00130
# data/train/part-r-00131
# data/train/part-r-00132
# data/train/part-r-00133
# data/train/part-r-00134
# data/train/part-r-00135
# data/train/part-r-00136
# data/train/part-r-00137
# data/train/part-r-00138
# data/train/part-r-00139
# data/train/part-r-00140
# data/train/part-r-00141
# data/train/part-r-00142
# data/train/part-r-00143
# data/train/part-r-00144
# data/train/part-r-00145
# data/train/part-r-00146
# data/train/part-r-00147
# data/train/part-r-00148
# data/train/part-r-00149
# data/train/part-r-00150
# data/train/part-r-00151
# data/train/part-r-00152
# data/train/part-r-00153
# data/train/part-r-00154
# data/train/part-r-00155
# data/train/part-r-00156
# data/train/part-r-00157
# data/train/part-r-00158
# data/train/part-r-00159
# data/train/part-r-00160
# data/train/part-r-00161
# data/train/part-r-00162
# data/train/part-r-00163
# data/train/part-r-00164
# data/train/part-r-00165
# data/train/part-r-00166
# data/train/part-r-00167
# data/train/part-r-00168
# data/train/part-r-00169
# data/train/part-r-00170
# data/train/part-r-00171
# data/train/part-r-00172
# data/train/part-r-00173
# data/train/part-r-00174
# data/train/part-r-00175
# data/train/part-r-00176
# data/train/part-r-00177
# data/train/part-r-00178
# data/train/part-r-00179
# data/train/part-r-00180
# data/train/part-r-00181
# data/train/part-r-00182
# data/train/part-r-00183
# data/train/part-r-00184
# data/train/part-r-00185
# data/train/part-r-00186
# data/train/part-r-00187
# data/train/part-r-00188
# data/train/part-r-00189
# data/train/part-r-00190
# data/train/part-r-00191
# data/train/part-r-00192
# data/train/part-r-00193
# data/train/part-r-00194
# data/train/part-r-00195
# data/train/part-r-00196
# data/train/part-r-00197
# data/train/part-r-00198
# data/train/part-r-00199
# data/train/part-r-01000
# data/train/part-r-01001
# data/train/part-r-01002
# data/train/part-r-01003
# data/train/part-r-01004
# data/train/part-r-01005
# data/train/part-r-01006
# data/train/part-r-01007
# data/train/part-r-01008
# data/train/part-r-01009
# data/train/part-r-01010
# data/train/part-r-01011
# data/train/part-r-01012
# data/train/part-r-01013
# data/train/part-r-01014
# data/train/part-r-01015
# data/train/part-r-01016
# data/train/part-r-01017
# data/train/part-r-01018
# data/train/part-r-01019
# data/train/part-r-01020
# data/train/part-r-01021
# data/train/part-r-01022
# data/train/part-r-01023
# data/train/part-r-01024
# data/train/part-r-01025
# data/train/part-r-01026
# data/train/part-r-01027
# data/train/part-r-01028
# data/train/part-r-01029
# data/train/part-r-01030
# data/train/part-r-01031
# data/train/part-r-01032
# data/train/part-r-01033
# data/train/part-r-01034
# data/train/part-r-01035
# data/train/part-r-01036
# data/train/part-r-01037
# data/train/part-r-01038
# data/train/part-r-01039
# data/train/part-r-01040
# data/train/part-r-01041
# data/train/part-r-01042
# data/train/part-r-01043
# data/train/part-r-01044
# data/train/part-r-01045
# data/train/part-r-01046
# data/train/part-r-01047
# data/train/part-r-01048
# data/train/part-r-01049
# data/train/part-r-01050
# data/train/part-r-01051
# data/train/part-r-01052
# data/train/part-r-01053
# data/train/part-r-01054
# data/train/part-r-01055
# data/train/part-r-01056
# data/train/part-r-01057
# data/train/part-r-01058
# data/train/part-r-01059
# data/train/part-r-01060
# data/train/part-r-01061
# data/train/part-r-01062
# data/train/part-r-01063
# data/train/part-r-01064
# data/train/part-r-01065
# data/train/part-r-01066
# data/train/part-r-01067
# data/train/part-r-01068
# data/train/part-r-01069
# data/train/part-r-01070
# data/train/part-r-01071
# data/train/part-r-01072
# data/train/part-r-01073
# data/train/part-r-01074
# data/train/part-r-01075
# data/train/part-r-01076
# data/train/part-r-01077
# data/train/part-r-01078
# data/train/part-r-01079
# data/train/part-r-01080
# data/train/part-r-01081
# data/train/part-r-01082
# data/train/part-r-01083
# data/train/part-r-01084
# data/train/part-r-01085
# data/train/part-r-01086
# data/train/part-r-01087
# data/train/part-r-01088
# data/train/part-r-01089
# data/train/part-r-01090
# data/train/part-r-01091
# data/train/part-r-01092
# data/train/part-r-01093
# data/train/part-r-01094
# data/train/part-r-01095
# data/train/part-r-01096
# data/train/part-r-01097
# data/train/part-r-01098
# data/train/part-r-01099
# data/train/part-r-01100
# data/train/part-r-01101
# data/train/part-r-01102
# data/train/part-r-01103
# data/train/part-r-01104
# data/train/part-r-01105
# data/train/part-r-01106
# data/train/part-r-01107
# data/train/part-r-01108
# data/train/part-r-01109
# data/train/part-r-01110
# data/train/part-r-01111
# data/train/part-r-01112
# data/train/part-r-01113
# data/train/part-r-01114
# data/train/part-r-01115
# data/train/part-r-01116
# data/train/part-r-01117
# data/train/part-r-01118
# data/train/part-r-01119
# data/train/part-r-01120
# data/train/part-r-01121
# data/train/part-r-01122
# data/train/part-r-01123
# data/train/part-r-01124
# data/train/part-r-01125
# data/train/part-r-01126
# data/train/part-r-01127
# data/train/part-r-01128
# data/train/part-r-01129
# data/train/part-r-01130
# data/train/part-r-01131
# data/train/part-r-01132
# data/train/part-r-01133
# data/train/part-r-01134
# data/train/part-r-01135
# data/train/part-r-01136
# data/train/part-r-01137
# data/train/part-r-01138
# data/train/part-r-01139
# data/train/part-r-01140
# data/train/part-r-01141
# data/train/part-r-01142
# data/train/part-r-01143
# data/train/part-r-01144
# data/train/part-r-01145
# data/train/part-r-01146
# data/train/part-r-01147
# data/train/part-r-01148
# data/train/part-r-01149
# data/train/part-r-01150
# data/train/part-r-01151
# data/train/part-r-01152
# data/train/part-r-01153
# data/train/part-r-01154
# data/train/part-r-01155
# data/train/part-r-01156
# data/train/part-r-01157
# data/train/part-r-01158
# data/train/part-r-01159
# data/train/part-r-01160
# data/train/part-r-01161
# data/train/part-r-01162
# data/train/part-r-01163
# data/train/part-r-01164
# data/train/part-r-01165
# data/train/part-r-01166
# data/train/part-r-01167
# data/train/part-r-01168
# data/train/part-r-01169
# data/train/part-r-01170
# data/train/part-r-01171
# data/train/part-r-01172
# data/train/part-r-01173
# data/train/part-r-01174
# data/train/part-r-01175
# data/train/part-r-01176
# data/train/part-r-01177
# data/train/part-r-01178
# data/train/part-r-01179
# data/train/part-r-01180
# data/train/part-r-01181
# data/train/part-r-01182
# data/train/part-r-01183
# data/train/part-r-01184
# data/train/part-r-01185
# data/train/part-r-01186
# data/train/part-r-01187
# data/train/part-r-01188
# data/train/part-r-01189
# data/train/part-r-01190
# data/train/part-r-01191
# data/train/part-r-01192
# data/train/part-r-01193
# data/train/part-r-01194
# data/train/part-r-01195
# data/train/part-r-01196
# data/train/part-r-01197
# data/train/part-r-01198
# data/train/part-r-01199

# %%
images = []

for blob in blobs:
    # transform data format
    parsed_img = parse_visual(blob) # parse satellite image data
    img_sat = get_img_from_example(parsed_img[0]) # convert data to rgbArray with label
    
    # append image to list
    images.append(img_sat)

images
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/q5/2d8pwqf14mv_nz14d23_2b040000gn/T/ipykernel_79717/1878140325.py in <module>
#       1 images = []
#       2
# ----> 3 for blob in blobs:
#       4     # Do stuff to file (transform data format)
#       5     parsed_img = parse_visual(blob) # parse satellite image data
#
# ~/.pyenv/versions/lewagon/lib/python3.8/site-packages/google/api_core/page_iterator.py in __iter__(self)
#     227         """
#     228         if self._started:
# --> 229             raise ValueError("Iterator has already started", self)
#     230         self._started = True
#     231         return self._items_iter()
#
# ValueError: ('Iterator has already started', <google.api_core.page_iterator.HTTPIterator object at 0x18f693e80>)

# %% [markdown]
# ## load blobs in for loop

# %%
def get_images_gcp(n=10):
    '''
    This function gets images from the cloud in the correct format.
    The function downloads images into temporary files, does a transformation, and then deletes the temporary file.
    '''
    
    # GCP bucket parameters
    project_name = 'drought-detection'
    bucket_name = 'wagon-data-batch913-drought_detection'

    # open client and get blobs
    storage_client = storage.Client(project=project_name)
    blobs = storage_client.list_blobs(bucket_name, prefix='data/train/part', delimiter='/')
    
    images = []

    for blob in blobs:
        # # create temporary file
        _, temp_local_filename = tempfile.mkstemp()

        # Download file from bucket
        blob.download_to_filename(temp_local_filename)
        # temp_local_filename = blob.download_as_bytes() # tried downloading TFRecords in different format
        
        # Do stuff to file (transform data format)
        parsed_img = parse_visual(temp_local_filename) # parse satellite image data
        img_sat = get_img_from_example(parsed_img[0]) # convert data to rgbArray with label

        # append image to list
        images.append(img_sat)
        
        # # remove temporary file
        os.remove(temp_local_filename)
        
    return np.array(images)

# %%
# load images
images = get_images_gcp()
# Out:
# ---------------------------------------------------------------------------
# InvalidResponse                           Traceback (most recent call last)
# ~/.pyenv/versions/lewagon/lib/python3.8/site-packages/google/cloud/storage/client.py in download_blob_to_file(self, blob_or_uri, file_obj, start, end, raw_download, if_etag_match, if_etag_not_match, if_generation_match, if_generation_not_match, if_metageneration_match, if_metageneration_not_match, timeout, checksum, retry)
#    1141         try:
# -> 1142             blob_or_uri._do_download(
#    1143                 transport,
#
# ~/.pyenv/versions/lewagon/lib/python3.8/site-packages/google/cloud/storage/blob.py in _do_download(self, transport, file_obj, download_url, headers, start, end, raw_download, timeout, checksum, retry)
#     988             download._retry_strategy = retry_strategy
# --> 989             response = download.consume(transport, timeout=timeout)
#     990             self._extract_headers_from_download(response)
#
# ~/.pyenv/versions/lewagon/lib/python3.8/site-packages/google/resumable_media/requests/download.py in consume(self, transport, timeout)
#     213
# --> 214         return _request_helpers.wait_and_retry(
#     215             retriable_request, self._get_status_code, self._retry_strategy
#
# ~/.pyenv/versions/lewagon/lib/python3.8/site-packages/google/resumable_media/requests/_request_helpers.py in wait_and_retry(func, get_status_code, retry_strategy)
#     147         try:
# --> 148             response = func()
#     149         except _CONNECTION_ERROR_CLASSES as e:
#
# ~/.pyenv/versions/lewagon/lib/python3.8/site-packages/google/resumable_media/requests/download.py in retriable_request()
#     206
# --> 207             self._process_response(result)
#     208
#
# ~/.pyenv/versions/lewagon/lib/python3.8/site-packages/google/resumable_media/_download.py in _process_response(self, response)
#     187         self._finished = True
# --> 188         _helpers.require_status_code(
#     189             response, _ACCEPTABLE_STATUS_CODES, self._get_status_code
#
# ~/.pyenv/versions/lewagon/lib/python3.8/site-packages/google/resumable_media/_helpers.py in require_status_code(response, status_codes, get_status_code, callback)
#     104             callback()
# --> 105         raise common.InvalidResponse(
#     106             response,
#
# InvalidResponse: ('Request failed with status code', 403, 'Expected one of', <HTTPStatus.OK: 200>, <HTTPStatus.PARTIAL_CONTENT: 206>)
#
# During handling of the above exception, another exception occurred:
#
# Forbidden                                 Traceback (most recent call last)
# /var/folders/q5/2d8pwqf14mv_nz14d23_2b040000gn/T/ipykernel_79717/3440604606.py in <module>
# ----> 1 images = get_images_gcp()
#
# /var/folders/q5/2d8pwqf14mv_nz14d23_2b040000gn/T/ipykernel_79717/831085853.py in get_images_gcp(n)
#      17
#      18         # Download file from bucket
# ---> 19         blob.download_to_filename(temp_local_filename)
#      20         # temp_local_filename = blob.download_as_bytes()
#      21
#
# ~/.pyenv/versions/lewagon/lib/python3.8/site-packages/google/cloud/storage/blob.py in download_to_filename(self, filename, client, start, end, raw_download, if_etag_match, if_etag_not_match, if_generation_match, if_generation_not_match, if_metageneration_match, if_metageneration_not_match, timeout, checksum, retry)
#    1268         try:
#    1269             with open(filename, "wb") as file_obj:
# -> 1270                 client.download_blob_to_file(
#    1271                     self,
#    1272                     file_obj,
#
# ~/.pyenv/versions/lewagon/lib/python3.8/site-packages/google/cloud/storage/client.py in download_blob_to_file(self, blob_or_uri, file_obj, start, end, raw_download, if_etag_match, if_etag_not_match, if_generation_match, if_generation_not_match, if_metageneration_match, if_metageneration_not_match, timeout, checksum, retry)
#    1153             )
#    1154         except resumable_media.InvalidResponse as exc:
# -> 1155             _raise_from_invalid_response(exc)
#    1156
#    1157     def list_blobs(
#
# ~/.pyenv/versions/lewagon/lib/python3.8/site-packages/google/cloud/storage/blob.py in _raise_from_invalid_response(error)
#    4455     message = f"{response.request.method} {response.request.url}: {error_message}"
#    4456
# -> 4457     raise exceptions.from_http_status(response.status_code, message, response=response)
#    4458
#    4459
#
# Forbidden: 403 GET https://storage.googleapis.com/download/storage/v1/b/wagon-data-batch913-drought_detection/o/data%2Ftrain%2Fpart-r-00000?generation=1657545621344585&alt=media: helyne@disco-genius-351114.iam.gserviceaccount.com does not have storage.objects.get access to the Google Cloud Storage object.: ('Request failed with status code', 403, 'Expected one of', <HTTPStatus.OK: 200>, <HTTPStatus.PARTIAL_CONTENT: 206>)

# %%
# check shape
images.shape
